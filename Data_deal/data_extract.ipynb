# %%
import pandas as pd
import numpy as np

# %%
early_24hr_aki=pd.read_csv("F:\TrainTest\EICU\Data_deal\early_24hr_aki.csv")
early_24hr_aki
# Out:
#        PatientStayID  unitdischargeoffset  24hr_AKI
# 0           242154.0                 8792     False
# 1           242290.0                 1656      True
# 2           242474.0                 1494     False
# 3           242505.0                 6920     False
# 4           242714.0                 2985     False
# ...              ...                  ...       ...
# 27934      3351486.0                12305     False
# 27935      3351989.0                 6500      True
# 27936      3352797.0                 8881     False
# 27937      3353097.0                 3881      True
# 27938      3353197.0                29871     False
#
# [27939 rows x 3 columns]

# %%
early_24hr_comorbidity=pd.read_csv('F:\TrainTest\EICU\Data_deal\early_24hr_comorbidity.csv')
early_24hr_comorbidity
# Out:
#       PatientStayID  comorbidity_elixhauser
# 0          200001.0                      20
# 1          200028.0                      21
# 2          200035.0                      10
# 3          200040.0                      11
# 4          200049.0                      25
# ...             ...                     ...
# 5294       299933.0                      10
# 5295       299949.0                      12
# 5296       299950.0                      20
# 5297       299957.0                      18
# 5298       299979.0                       9
#
# [5299 rows x 2 columns]

# %%
early_24hr_drug=pd.read_csv("F:\TrainTest\EICU\Data_deal\early_24hr_drug.csv")
early_24hr_drug
# Out:
#       PatientStayID  delirium_positive
# 0          200001.0                0.0
# 1          200016.0                0.0
# 2          200028.0                0.0
# 3          200034.0                1.0
# 4          200035.0                0.0
# ...             ...                ...
# 6804       299949.0                0.0
# 6805       299950.0                0.0
# 6806       299957.0                0.0
# 6807       299962.0                0.0
# 6808       299979.0                0.0
#
# [6809 rows x 2 columns]

# %%
early_24hr_eicu=pd.read_csv("F:\TrainTest\EICU\Data_deal\early_24hr_eicu.csv")
early_24hr_eicu
# Out:
#        PatientStayID  Class  unitdischargeoffset_x  apachescore  gender   age  \
# 0             242154      1                   8792         77.0  Female  46.0
# 1             242290      0                   1656         77.0  Female  75.0
# 2             242474      0                   1494         64.0    Male  52.0
# 3             242505      1                   6920         78.0  Female  90.0
# 4             242714      0                   2985         -1.0    Male  78.0
# ...              ...    ...                    ...          ...     ...   ...
# 18300        3352193      0                   1955         -1.0  Female  19.0
# 18301        3352331      0                   2204         48.0  Female  75.0
# 18302        3352964      0                   2466         75.0  Female  85.0
# 18303        3353044      0                   4788         41.0    Male  52.0
# 18304        3353077      0                   6050         36.0  Female  60.0
#
# ...

# %%
early_24hr_static_features=pd.read_csv("F:\TrainTest\EICU\Data_deal\early_24hr_static_features.csv")
early_24hr_static_features
# Out:
#        PatientStayID  unitdischargeoffset  apachescore  gender   age  \
# 0           242154.0                 8792         77.0  Female  46.0
# 1           242290.0                 1656         77.0  Female  75.0
# 2           242474.0                 1494         64.0    Male  52.0
# 3           242505.0                 6920         78.0  Female  90.0
# 4           242714.0                 2985         -1.0    Male  78.0
# ...              ...                  ...          ...     ...   ...
# 27934      3351486.0                12305         35.0  Female  25.0
# 27935      3351989.0                 6500         53.0    Male  31.0
# 27936      3352797.0                 8881          NaN  Female  67.0
# 27937      3353097.0                 3881         89.0  Female  41.0
# 27938      3353197.0                29871          NaN  Female  66.0
#
#               ethnicity  hospitalid  \
# 0             Caucasian          79
# 1         Other/Unknown          79
# ...

# %%
early_24hr_temperature=pd.read_csv("F:\TrainTest\EICU\Data_deal\early_24hr_temperature.csv")
early_24hr_temperature
# Out:
#       PatientStayID  24hr_mean_temp  24hr_minimum_temp  24hr_maximum_temp
# 0          200001.0       37.175926          36.388889          37.666667
# 1          200016.0       36.092593          35.111111          37.222222
# 2          200028.0       36.829060          36.111111          37.666667
# 3          200034.0       36.270833          33.888889          38.000000
# 4          200035.0       36.907407          36.277778          37.222222
# ...             ...             ...                ...                ...
# 6804       299949.0       37.324074          37.000000          37.666667
# 6805       299950.0       36.777778          36.611111          36.888889
# 6806       299957.0       36.550000          35.500000          37.166667
# 6807       299962.0       36.527778          35.888889          36.944444
# 6808       299979.0       36.675926          36.222222          36.944444
#
# [6809 rows x 4 columns]
